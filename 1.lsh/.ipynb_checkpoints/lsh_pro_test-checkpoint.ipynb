# %%
import random
import pprint
import types
import numpy as np
import pandas as pd
import func
from IPython.core.debugger import Tracer
from collections import defaultdict
from operator import itemgetter
from pylab import *
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

import l2_hash_family
import cosine_hash_family
import lsh_tester
import lsh_index

from lsh_index import LSHIndex
from l2_hash_family import L2HashFamily
from cosine_hash_family import CosineHashFamily
from lsh_tester import LSHTester

# %%
# create random 3D unit vector

d = 3
num_points = 1000
points = []
for _ in xrange(num_points):
    points.append(list(func.random_three_vector()))
# pprint.pprint(points)

# %matplotlib notebook
fig = plt.figure()
ax = fig.gca(projection='3d')

p_array = np.asarray(points)
ax.plot(p_array[:,0],p_array[:,1],p_array[:,2],'o')
# Out:
# <img src="data:image/png;base64,...">

# %%
# create points

# create a test dataset of vectors of integers
d = 5
xmax = 20
num_points = 5

points = [[random.randint(-xmax,xmax) for i in xrange(d)] for j in xrange(num_points)]
pprint.pprint(points)
print "------------------------------"
print points[0][:]
# Out:
# [[3, -13, -17, -18, 16],
#  [7, 14, -9, 10, 5],
#  [-17, 14, -7, -9, -16],
#  [18, 12, -17, 10, 9],
#  [19, -4, -20, 4, -12]]
# ------------------------------
# [3, -13, -17, -18, 16]

# %%
# seed the dataset with a fixed number of nearest neighbours
# within a given small "radius"
num_neighbours = 2
radius = 0.1
for point in points[:num_points]:
    for i in xrange(num_neighbours):
        points.append([x+random.uniform(-radius,radius) for x in point])
pprint.pprint(points, width= 200)
# Out:
# [(0.67731926208987059, -0.41384855330492448, -0.60824994215326822),
#  (0.051118377342951965, 0.92695589884145946, -0.37167145855021677),
#  (0.77828492211965217, 0.12934662434234051, 0.61444448957773923),
#  (0.81401700151023948, -0.36032766824845675, 0.45556590384587492),
#  (0.12306449182580889, -0.98945665842062902, -0.076358705847716646),
#  [0.60618717539276579, -0.39438292861653224, -0.62618839467492293],
#  [0.65117330258339878, -0.3721508224584022, -0.59432500512605424],
#  [0.0076720478322630445, 0.85867467498127004, -0.3892841171906104],
#  [0.018528809729785711, 0.90634914260556099, -0.41140547499297742],
#  [0.72364200718217486, 0.072108836262334108, 0.52938983213621871],
#  [0.81457443452520351, 0.041414991863652259, 0.65342494052956956],
#  [0.87058172599999872, -0.44500002312404274, 0.37326313973278247],
#  [0.73889680939566127, -0.36448466129530921, 0.38970523080861014],
#  [0.078868236212580073, -1.083302318254471, -0.10604516548742196],
#  [0.16755946228275712, -0.95584021631848815, -0.15378994633144571]]

# %%
# Cos distance
k = 8 # num of projection
l_index = 2 # of hash table
hfamily = CosineHashFamily(d)
lsh = LSHIndex(hfamily, k, l_index)
pprint.pprint(lsh.__dict__)

pprint.pprint(lsh.hash_family.__dict__)

for g,table in lsh.hash_tables: 
    for ix, p in enumerate(points):
        hash_value = lsh.hash(g,p)
        point_hash = (p, hash_value)
        print point_hash
# Out:
# {'L': 0,
#  'hash_family': <cosine_hash_family.CosineHashFamily instance at 0x6d3bce68>,
#  'hash_tables': [([<cosine_hash_family.CosineHash instance at 0x6d3bc238>,
#                    <cosine_hash_family.CosineHash instance at 0x6d3bc378>,
#                    <cosine_hash_family.CosineHash instance at 0x6d3bc148>,
#                    <cosine_hash_family.CosineHash instance at 0x6d3bca30>,
#                    <cosine_hash_family.CosineHash instance at 0x6d3bc800>,
#                    <cosine_hash_family.CosineHash instance at 0x6d3bc1e8>,
#                    <cosine_hash_family.CosineHash instance at 0x6d3bcd78>,
#                    <cosine_hash_family.CosineHash instance at 0x6d3bcdf0>],
#                   defaultdict(<function <lambda> at 0x6d39c6b0>, {})),
#                  ([<cosine_hash_family.CosineHash instance at 0x6d3bccb0>,
#                    <cosine_hash_family.CosineHash instance at 0x6d3bce90>,
#                    <cosine_hash_family.CosineHash instance at 0x6d3bceb8>,
#                    <cosine_hash_family.CosineHash instance at 0x6d3bcee0>,
#                    <cosine_hash_family.CosineHash instance at 0x6d3bcf08>,
#                    <cosine_hash_family.CosineHash instance at 0x6d3bcf30>,
#                    <cosine_hash_family.CosineHash instance at 0x6d3bcf58>,
#                    <cosine_hash_family.CosineHash instance at 0x6d3bcf80>],
#                   defaultdict(<function <lambda> at 0x6d39cdf0>, {}))],
#  'k': 8}
# {'d': 3}
# ((0.67731926208987059, -0.41384855330492448, -0.60824994215326822), 216)
# ((0.051118377342951965, 0.92695589884145946, -0.37167145855021677), 226)
# ((0.77828492211965217, 0.12934662434234051, 0.61444448957773923), 112)
# ((0.81401700151023948, -0.36032766824845675, 0.45556590384587492), 120)
# ((0.12306449182580889, -0.98945665842062902, -0.076358705847716646), 221)
# ([0.60618717539276579, -0.39438292861653224, -0.62618839467492293], 216)
# ([0.65117330258339878, -0.3721508224584022, -0.59432500512605424], 216)
# ([0.0076720478322630445, 0.85867467498127004, -0.3892841171906104], 162)
# ([0.018528809729785711, 0.90634914260556099, -0.41140547499297742], 162)
# ([0.72364200718217486, 0.072108836262334108, 0.52938983213621871], 112)
# ([0.81457443452520351, 0.041414991863652259, 0.65342494052956956], 112)
# ([0.87058172599999872, -0.44500002312404274, 0.37326313973278247], 88)
# ([0.73889680939566127, -0.36448466129530921, 0.38970523080861014], 88)
# ([0.078868236212580073, -1.083302318254471, -0.10604516548742196], 157)
# ([0.16755946228275712, -0.95584021631848815, -0.15378994633144571], 221)
# ((0.67731926208987059, -0.41384855330492448, -0.60824994215326822), 185)
# ((0.051118377342951965, 0.92695589884145946, -0.37167145855021677), 9)
# ((0.77828492211965217, 0.12934662434234051, 0.61444448957773923), 50)
# ((0.81401700151023948, -0.36032766824845675, 0.45556590384587492), 182)
# ((0.12306449182580889, -0.98945665842062902, -0.076358705847716646), 244)
# ([0.60618717539276579, -0.39438292861653224, -0.62618839467492293], 185)
# ([0.65117330258339878, -0.3721508224584022, -0.59432500512605424], 185)
# ([0.0076720478322630445, 0.85867467498127004, -0.3892841171906104], 9)
# ([0.018528809729785711, 0.90634914260556099, -0.41140547499297742], 9)
# ([0.72364200718217486, 0.072108836262334108, 0.52938983213621871], 50)
# ([0.81457443452520351, 0.041414991863652259, 0.65342494052956956], 50)
# ([0.87058172599999872, -0.44500002312404274, 0.37326313973278247], 182)
# ([0.73889680939566127, -0.36448466129530921, 0.38970523080861014], 182)
# ([0.078868236212580073, -1.083302318254471, -0.10604516548742196], 244)
# ([0.16755946228275712, -0.95584021631848815, -0.15378994633144571], 244)

# %%
# l2_norm

k = 3 # num of projection
l_index = 3 # of hash table
hfamily = L2HashFamily(10,d)
lsh = LSHIndex(hfamily, k, l_index)
pprint.pprint(lsh.__dict__)

pprint.pprint(lsh.hash_family.__dict__)

for g,table in lsh.hash_tables: 
    for ix, p in enumerate(points):
        hash_value = lsh.hash(g,p)
        point_hash = (p, hash_value)
        print point_hash
# Out:
# {'L': 0,
#  'hash_family': <l2_hash_family.L2HashFamily instance at 0x6d479198>,
#  'hash_tables': [([<l2_hash_family.L2Hash instance at 0x6d4791e8>,
#                    <l2_hash_family.L2Hash instance at 0x6d479210>,
#                    <l2_hash_family.L2Hash instance at 0x6d479238>],
#                   defaultdict(<function <lambda> at 0x6d471e30>, {})),
#                  ([<l2_hash_family.L2Hash instance at 0x6d4792b0>,
#                    <l2_hash_family.L2Hash instance at 0x6d479300>,
#                    <l2_hash_family.L2Hash instance at 0x6d479350>],
#                   defaultdict(<function <lambda> at 0x6d471f70>, {})),
#                  ([<l2_hash_family.L2Hash instance at 0x6d4793c8>,
#                    <l2_hash_family.L2Hash instance at 0x6d479418>,
#                    <l2_hash_family.L2Hash instance at 0x6d479468>],
#                   defaultdict(<function <lambda> at 0x6d471cf0>, {}))],
#  'k': 3}
# {'d': 5, 'w': 10}
# ([195, 106, 121, 65, 171], '[-2, 73, 8]')
# ([48, 25, 115, 155, 53], '[15, 15, 15]')
# ([175, 148, 87, 143, 16], '[20, 41, 52]')
# ([92, 108, 63, 175, 63], '[21, 25, 33]')
# ([134, 60, 177, 50, 179], '[-8, 69, -7]')
# ([17, 142, 54, 145, 142], '[11, 34, 15]')
# ([174, 51, 53, 183, 27], '[25, 20, 37]')
# ([130, 48, 56, 95, 91], '[8, 33, 11]')
# ([35, 26, 16, 134, 30], '[17, 0, 16]')
# ([138, 115, 58, 129, 174], '[8, 52, 11]')
# ([195, 106, 121, 65, 171], '[-11, 26, 4]')
# ([48, 25, 115, 155, 53], '[11, 18, -6]')
# ([175, 148, 87, 143, 16], '[-7, 12, 21]')
# ([92, 108, 63, 175, 63], '[5, 19, -2]')
# ([134, 60, 177, 50, 179], '[-2, 32, -1]')
# ([17, 142, 54, 145, 142], '[13, 38, -20]')
# ([174, 51, 53, 183, 27], '[-5, 0, 7]')
# ([130, 48, 56, 95, 91], '[-5, 11, 0]')
# ([35, 26, 16, 134, 30], '[6, 7, -8]')
# ([138, 115, 58, 129, 174], '[-2, 27, -11]')
# ([195, 106, 121, 65, 171], '[-3, 7, -63]')
# ([48, 25, 115, 155, 53], '[25, -11, -11]')
# ([175, 148, 87, 143, 16], '[17, -6, -58]')
# ([92, 108, 63, 175, 63], '[27, -15, -34]')
# ([134, 60, 177, 50, 179], '[-7, 13, -40]')
# ([17, 142, 54, 145, 142], '[17, -10, -21]')
# ([174, 51, 53, 183, 27], '[35, -21, -49]')
# ([130, 48, 56, 95, 91], '[13, -7, -39]')
# ([35, 26, 16, 134, 30], '[27, -18, -11]')
# ([138, 115, 58, 129, 174], '[14, -8, -51]')

# %%
# Start from here:

# seed the dataset with a fixed number of nearest neighbours
# within a given small "radius"
num_neighbours = 2
radius = 0.1
for point in points[:num_points]:
    for i in xrange(num_neighbours):
        points.append([x+random.uniform(-radius,radius) for x in point])
# pprint.pprint(points, width= 200)

# test lsh versus brute force comparison by running a grid
# search for the best lsh parameter values for each family
# tester = LSHTester(points,points[:num_points/10],num_neighbours)
tester = LSHTester(points,points[:num_points/10],num_neighbours)
# pprint.pprint(tester.__dict__, width= 200)

args = {'name':'L2',
        'metric':l2_hash_family.L2_norm,
        'hash_family':L2HashFamily(10*radius,d),
        'k_vals':[2],
        'L_vals':[2]}
tester.run(**args)
